# %%
import numpy as np
np.random.seed(1337)
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
X = np.linspace(-1, 1, 200) #在-1和1之间均分200个数
Y = 0.5*X + 2 + np.random.normal(0, 0.03, 200)# 正态分布
plt.scatter(X, Y)
plt.show()

# %%
X_train, Y_train = X[:160], Y[:160]
X_test, Y_test = X[160:], Y[160:]

# %%
model = Sequential()
model.add(Dense(units = 3, input_dim = 1))
model.add(Dense(units = 1))
model.compile(loss = 'mse', optimizer = 'sgd')

# %%
print('Training ------------------')
for step in range(301):
    cost = model.train_on_batch(X_train, Y_train)
    if step  % 100 == 0:
        print('train cost: ', cost)
# Out:
# Training ------------------
# train cost:  3.4065537
# train cost:  0.21235347
# train cost:  0.080607906
# train cost:  0.030339783

# %%
print('Test ------------------')
cost = model.evaluate(X_test, Y_test, batch_size = 40)
print('test cost:', cost)
W, b = model.layers[1].get_weights()
print('weights=', W, '\nbias=', b)
# Out:
# Test ------------------
# 40/40 [==============================] - 0s 893us/step
# test cost: 0.15133988857269287
# weights= [[-0.9587151 ]
#  [ 0.1840896 ]
#  [ 0.17332248]]
# bias= [1.0198708]

# %%
Y_pred = model.predict(X_train)
plt.scatter(X_train, Y_train)
plt.plot(X_train, Y_pred)
plt.show()

# %%
Y_pred = model.predict(X_test)
plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_pred)
plt.show()
